# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.25.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
data=pd.read_csv("/content/customer_basket.csv")
dat=data.copy()

# %%
 veri=dat.iloc[:,1]
 veri=pd.DataFrame(veri)

# %%
import pandas as pd
from ast import literal_eval  # Import literal_eval to safely evaluate strings containing Python expressions

# Assuming 'veri' is your DataFrame with the column 'list_of_goods'
veri['list_of_goods'] = veri['list_of_goods'].apply(lambda x: literal_eval(x) if isinstance(x, str) else x)

# Convert each row to a string with comma-separated items
veri['list_of_goods'] = veri['list_of_goods'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

print(veri)
# Out:
#                                            list_of_goods
# 0      olive oil, yogurt cake, grated cheese, cookies...
# 1      babies food, shower gel, rice, black beer, oli...
# 2      babies food, barbecue sauce, olive oil, butter...
# 3      babies food, milk, rice, yogurt cake, gums, st...
# 4      napkins, cookies, razor, cooking oil, water sp...
# ...                                                  ...
# 89947  rice, pet food, cauliflower, cake, cooking oil...
# 89948  cotton buds, cream, gums, cooking oil, cake, c...
# 89949  cottage cheese, champagne, spaghetti, vacuum c...
# 89950  chutney, samsung galaxy 10, catfish, tea, hone...
# 89951  cotton buds, phone car charger, cooking oil, c...
#
# [89952 rows x 1 columns]

# %%
veri=list(veri["list_of_goods"].apply(lambda x:x.split(",")))

# %%
te=TransactionEncoder()
tveri=te.fit_transform(veri)

# %%
veri=pd.DataFrame(tveri,columns=te.columns_)
print(veri)
# Out:
#         airpods   almonds   antioxydant juice   asparagus   avocado  \
# 0         False     False               False        True     False
# 1         False     False               False       False     False
# 2         False     False               False       False     False
# 3         False     False               False       False     False
# 4         False     False               False       False     False
# ...         ...       ...                 ...         ...       ...
# 89947     False     False               False       False     False
# 89948     False     False               False       False     False
# 89949     False     False               False       False     False
# 89950     False      True               False       False     False
# 89951     False     False               False       False     False
#
#         babies food   bacon   barbecue sauce   beats headphones   beer  ...  \
# 0             False   False            False              False  False  ...
# 1             False   False            False              False  False  ...
# 2             False   False             True              False  False  ...
# 3             False   False            False              False  False  ...
# 4             False   False            False              False  False  ...
# ...             ...     ...              ...                ...    ...  ...
# 89947         False   False            False              False  False  ...
# 89948         False   False            False              False  False  ...
# 89949         False   False            False              False  False  ...
# 89950         False   False            False              False  False  ...
# 89951         False   False            False              False  False  ...
#
#        vacuum cleaner  vegetables mix  water spray  white wine  \
# 0               False           False        False       False
# 1               False           False        False       False
# 2               False           False        False       False
# 3               False           False        False       False
# 4               False           False        False       False
# ...               ...             ...          ...         ...
# 89947           False           False        False       False
# 89948           False           False        False       False
# 89949           False           False        False       False
# 89950           False           False        False       False
# 89951           False           False        False       False
#
#        whole weat flour  whole wheat pasta  whole wheat rice   yams  \
# 0                 False              False             False  False
# 1                 False              False             False  False
# 2                 False              False             False  False
# 3                 False              False             False  False
# 4                 False              False             False  False
# ...                 ...                ...               ...    ...
# 89947             False              False             False  False
# 89948             False              False             False  False
# 89949             False              False             False  False
# 89950             False              False             False  False
# 89951             False              False             False  False
#
#        yogurt cake  zucchini
# 0            False     False
# 1            False     False
# 2            False     False
# 3            False     False
# 4            False     False
# ...            ...       ...
# 89947        False     False
# 89948        False     False
# 89949        False     False
# 89950        False     False
# 89951        False     False
#
# [89952 rows x 324 columns]

# %%
veri.columns = veri.columns.str.strip()

# Tüm sütun adlarını yazdır
print(veri.columns)
# Out:
# Index(['airpods', 'almonds', 'antioxydant juice', 'asparagus', 'avocado',
#        'babies food', 'bacon', 'barbecue sauce', 'beats headphones', 'beer',
#        ...
#        'vacuum cleaner', 'vegetables mix', 'water spray', 'white wine',
#        'whole weat flour', 'whole wheat pasta', 'whole wheat rice', 'yams',
#        'yogurt cake', 'zucchini'],
#       dtype='object', length=324)

# %%
for sütun in veri.columns:
    print(sütun)
# Out:
# airpods
# almonds
# antioxydant juice
# asparagus
# avocado
# babies food
# bacon
# barbecue sauce
# beats headphones
# beer
# black beer
# black tea
# blueberries
# bluetooth headphones
# body spray
# bramble
# brownies
# burger sauce
# burgers
# butter
# cake
# candy bars
# canned_tuna
# carrots
# catfish
# cauliflower
# cereals
# champagne
# chicken
# chili
# chocolate
# chocolate bread
# chutney
# cider
# cologne
# cookies
# cooking oil
# corn
# cottage cheese
# cotton buds
# cream
# deodorant
# dessert wine
# eggplant
# eggs
# energy bar
# energy drink
# escalope
# extra dark chocolate
# final fantasy XIX
# final fantasy XX
# final fantasy XXII
# flax seed
# french fries
# french wine
# fresh bread
# fresh tuna
# fromage blanc
# frozen smoothie
# frozen vegetables
# gluten free bar
# google tablet
# grated cheese
# green beans
# green grapes
# green tea
# ground beef
# gums
# half-life 2
# half-life: alyx
# ham
# hand protein bar
# herb & pepper
# honey
# hot dogs
# iMac
# iPad
# iphone 8
# ketchup
# laptop
# light cream
# light mayo
# low fat yogurt
# mashed potato
# mayonnaise
# meatballs
# megaman zero
# megaman zero 2
# megaman zero 3
# megaman zero 4
# melons
# metroid fusion
# metroid prime
# milk
# minecraft
# mineral water
# mint
# mint green tea
# muffins
# mushroom cream sauce
# napkins
# nonfat milk
# oatmeal
# oil
# olive oil
# pancakes
# parmesan cheese
# pasta
# pepper
# pet food
# phone car charger
# phone charger
# pickles
# pokemon scarlet
# pokemon shield
# pokemon sword
# pokemon violet
# portal
# portal 2
# protein bar
# ratchet & clank
# ratchet & clank 2
# ratchet & clank 3
# razor
# red wine
# rice
# salad
# salmon
# salt
# samsung galaxy 10
# sandwich
# seabass
# shallot
# shampoo
# shower gel
# shrimp
# soda
# soup
# spaghetti
# sparkling water
# spinach
# strawberries
# strong cheese
# tea
# toilet paper
# tomato juice
# tomato sauce
# tomatoes
# tooth brush
# toothpaste
# trout
# turkey
# vacuum cleaner
# vegetables mix
# water spray
# white wine
# whole weat flour
# whole wheat pasta
# whole wheat rice
# yams
# yogurt cake
# zucchini
# airpods
# almonds
# antioxydant juice
# asparagus
# avocado
# babies food
# bacon
# barbecue sauce
# beats headphones
# beer
# black beer
# black tea
# blueberries
# bluetooth headphones
# body spray
# bramble
# brownies
# burger sauce
# burgers
# butter
# cake
# candy bars
# canned_tuna
# carrots
# catfish
# cauliflower
# cereals
# champagne
# chicken
# chili
# chocolate
# chocolate bread
# chutney
# cider
# cologne
# cookies
# cooking oil
# corn
# cottage cheese
# cotton buds
# cream
# deodorant
# dessert wine
# eggplant
# eggs
# energy bar
# energy drink
# escalope
# extra dark chocolate
# final fantasy XIX
# final fantasy XX
# final fantasy XXII
# flax seed
# french fries
# french wine
# fresh bread
# fresh tuna
# fromage blanc
# frozen smoothie
# frozen vegetables
# gluten free bar
# google tablet
# grated cheese
# green beans
# green grapes
# green tea
# ground beef
# gums
# half-life 2
# half-life: alyx
# ham
# hand protein bar
# herb & pepper
# honey
# hot dogs
# iMac
# iPad
# iphone 8
# ketchup
# laptop
# light cream
# light mayo
# low fat yogurt
# mashed potato
# mayonnaise
# meatballs
# megaman zero
# megaman zero 2
# megaman zero 3
# megaman zero 4
# melons
# metroid fusion
# metroid prime
# milk
# minecraft
# mineral water
# mint
# mint green tea
# muffins
# mushroom cream sauce
# napkins
# nonfat milk
# oatmeal
# oil
# olive oil
# pancakes
# parmesan cheese
# pasta
# pepper
# pet food
# phone car charger
# phone charger
# pickles
# pokemon scarlet
# pokemon shield
# pokemon sword
# pokemon violet
# portal
# portal 2
# protein bar
# ratchet & clank
# ratchet & clank 2
# ratchet & clank 3
# razor
# red wine
# rice
# salad
# salmon
# salt
# samsung galaxy 10
# sandwich
# seabass
# shallot
# shampoo
# shower gel
# shrimp
# soda
# soup
# spaghetti
# sparkling water
# spinach
# strawberries
# strong cheese
# tea
# toilet paper
# tomato juice
# tomato sauce
# tomatoes
# tooth brush
# toothpaste
# trout
# turkey
# vacuum cleaner
# vegetables mix
# water spray
# white wine
# whole weat flour
# whole wheat pasta
# whole wheat rice
# yams
# yogurt cake
# zucchini

# %%
unique_columns = veri.columns.unique()
unique_columns
# Out:
# Index(['airpods', 'almonds', 'antioxydant juice', 'asparagus', 'avocado',
#        'babies food', 'bacon', 'barbecue sauce', 'beats headphones', 'beer',
#        ...
#        'vacuum cleaner', 'vegetables mix', 'water spray', 'white wine',
#        'whole weat flour', 'whole wheat pasta', 'whole wheat rice', 'yams',
#        'yogurt cake', 'zucchini'],
#       dtype='object', length=162)

# %%
verix = veri.loc[:,~veri.columns.duplicated()]

# %%
print(verix)
# Out:
#        airpods  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0        False    False              False       True    False        False
# 1        False    False              False      False    False        False
# 2        False    False              False      False    False        False
# 3        False    False              False      False    False        False
# 4        False    False              False      False    False        False
# ...        ...      ...                ...        ...      ...          ...
# 89947    False    False              False      False    False        False
# 89948    False    False              False      False    False        False
# 89949    False    False              False      False    False        False
# 89950    False     True              False      False    False        False
# 89951    False    False              False      False    False        False
#
#        bacon  barbecue sauce  beats headphones   beer  ...  vacuum cleaner  \
# 0      False           False             False  False  ...           False
# 1      False           False             False  False  ...           False
# 2      False            True             False  False  ...           False
# 3      False           False             False  False  ...           False
# 4      False           False             False  False  ...           False
# ...      ...             ...               ...    ...  ...             ...
# 89947  False           False             False  False  ...           False
# 89948  False           False             False  False  ...           False
# 89949  False           False             False  False  ...            True
# 89950  False           False             False  False  ...           False
# 89951  False           False             False  False  ...           False
#
#        vegetables mix  water spray  white wine  whole weat flour  \
# 0               False        False       False             False
# 1               False        False       False             False
# 2               False        False       False             False
# 3               False        False       False             False
# 4               False         True       False             False
# ...               ...          ...         ...               ...
# 89947           False        False       False             False
# 89948           False        False       False             False
# 89949           False        False       False             False
# 89950           False        False       False             False
# 89951           False        False       False             False
#
#        whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                  False              True  False         True     False
# 1                  False              True  False        False     False
# 2                  False             False  False        False     False
# 3                  False             False  False         True     False
# 4                  False             False  False        False     False
# ...                  ...               ...    ...          ...       ...
# 89947              False              True  False        False     False
# 89948              False             False  False        False     False
# 89949              False             False  False        False     False
# 89950              False             False  False        False     False
# 89951              False              True  False        False     False
#
# [89952 rows x 162 columns]

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
df1=apriori(verix,min_support=0.05,use_colnames=True)
print(df1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                        itemsets
# 0   0.091838                       (airpods)
# 1   0.182620                     (asparagus)
# 2   0.050171                       (avocado)
# 3   0.080043          (bluetooth headphones)
# 4   0.256014                          (cake)
# ..       ...                             ...
# 78  0.058565         (cake, oil, candy bars)
# 79  0.092116        (cake, oil, cooking oil)
# 80  0.074106  (candy bars, oil, cooking oil)
# 81  0.062556        (cooking oil, oil, gums)
# 82  0.054151     (oil, muffins, cooking oil)
#
# [83 rows x 2 columns]

# %%
df1_sorted = df1.sort_values(by='support', ascending=False)
df1_sorted.head(30)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                   itemsets
# 31  0.336379                      (oil)
# 12  0.336302              (cooking oil)
# 4   0.256014                     (cake)
# 5   0.213014               (candy bars)
# 68  0.189334         (oil, cooking oil)
# 1   0.182620                (asparagus)
# 23  0.179785                     (gums)
# 29  0.160297                  (muffins)
# 9   0.151881                (champagne)
# 51  0.148001        (cake, cooking oil)
# 55  0.146289                (cake, oil)
# 42  0.146167                 (tomatoes)
# 30  0.129591                  (napkins)
# 6   0.125967                  (carrots)
# 39  0.124644                     (soup)
# 57  0.119708  (candy bars, cooking oil)
# 60  0.118452          (candy bars, oil)
# 19  0.114828              (fresh bread)
# 40  0.106001                (spaghetti)
# 18  0.103311             (french fries)
# 64  0.101877        (cooking oil, gums)
# 26  0.098797                  (ketchup)
# 72  0.097797                (oil, gums)
# 50  0.093794         (cake, candy bars)
# 79  0.092116   (cake, oil, cooking oil)
# 0   0.091838                  (airpods)
# 66  0.088592     (muffins, cooking oil)
# 74  0.086024             (oil, muffins)
# 49  0.084023      (tomatoes, asparagus)
# 28  0.083945            (mashed potato)

# %%
df2=association_rules(df1,metric="confidence",min_threshold=0.3)
print(df2)
# Out:
#                antecedents         consequents  antecedent support  \
# 0                (carrots)         (asparagus)            0.125967
# 1              (asparagus)           (carrots)            0.182620
# 2               (tomatoes)         (asparagus)            0.146167
# 3              (asparagus)          (tomatoes)            0.182620
# 4                   (cake)        (candy bars)            0.256014
# ..                     ...                 ...                 ...
# 56             (oil, gums)       (cooking oil)            0.097797
# 57                  (gums)  (oil, cooking oil)            0.179785
# 58          (muffins, oil)       (cooking oil)            0.086024
# 59  (muffins, cooking oil)               (oil)            0.088592
# 60               (muffins)  (oil, cooking oil)            0.160297
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.182620  0.070371    0.558644  3.059060  0.047367    1.851977
# 1             0.125967  0.070371    0.385341  3.059060  0.047367    1.421980
# 2             0.182620  0.084023    0.574840  3.147747  0.057330    1.922525
# 3             0.146167  0.084023    0.460096  3.147747  0.057330    1.581454
# 4             0.213014  0.093794    0.366364  1.719910  0.039260    1.242017
# ..                 ...       ...         ...       ...       ...         ...
# 56            0.336302  0.062556    0.639650  1.902013  0.029666    1.841815
# 57            0.189334  0.062556    0.347947  1.837739  0.028516    1.243251
# 58            0.336302  0.054151    0.629491  1.871805  0.025221    1.791314
# 59            0.336379  0.054151    0.611244  1.817125  0.024351    1.707034
# 60            0.189334  0.054151    0.337818  1.784242  0.023801    1.224234
#
#     zhangs_metric
# 0        0.770111
# 1        0.823487
# 2        0.799117
# 3        0.834755
# 4        0.562610
# ..            ...
# 56       0.525648
# 57       0.555773
# 58       0.509593
# 59       0.493391
# 60       0.523444
#
# [61 rows x 10 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df2_sorted = df2.sort_values(by='confidence', ascending=False)
df2_sorted.head(30)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   antecedents    consequents  antecedent support  \
# 56                (oil, gums)  (cooking oil)            0.097797
# 46                (cake, oil)  (cooking oil)            0.146289
# 58             (muffins, oil)  (cooking oil)            0.086024
# 41         (cake, candy bars)  (cooking oil)            0.093794
# 50          (candy bars, oil)  (cooking oil)            0.118452
# 44         (cake, candy bars)          (oil)            0.093794
# 47        (cake, cooking oil)          (oil)            0.148001
# 51  (candy bars, cooking oil)          (oil)            0.119708
# 55        (gums, cooking oil)          (oil)            0.101877
# 59     (muffins, cooking oil)          (oil)            0.088592
# 6                      (cake)  (cooking oil)            0.256014
# 22                  (carrots)     (tomatoes)            0.125967
# 2                  (tomatoes)    (asparagus)            0.146167
# 12                     (cake)          (oil)            0.256014
# 26                     (gums)  (cooking oil)            0.179785
# 31              (cooking oil)          (oil)            0.336302
# 30                      (oil)  (cooking oil)            0.336379
# 15               (candy bars)  (cooking oil)            0.213014
# 0                   (carrots)    (asparagus)            0.125967
# 29                  (napkins)  (cooking oil)            0.129591
# 19               (candy bars)          (oil)            0.213014
# 24              (fresh bread)  (cooking oil)            0.114828
# 28                  (muffins)  (cooking oil)            0.160297
# 32                     (soup)  (cooking oil)            0.124644
# 23             (french fries)  (cooking oil)            0.103311
# 39                     (soup)          (oil)            0.124644
# 35                     (gums)          (oil)            0.179785
# 27                  (ketchup)  (cooking oil)            0.098797
# 34              (fresh bread)          (oil)            0.114828
# 37                  (muffins)          (oil)            0.160297
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 56            0.336302  0.062556    0.639650  1.902013  0.029666    1.841815
# 46            0.336302  0.092116    0.629683  1.872376  0.042919    1.792245
# 58            0.336302  0.054151    0.629491  1.871805  0.025221    1.791314
# 41            0.336302  0.059043    0.629489  1.871800  0.027499    1.791306
# 50            0.336302  0.074106    0.625622  1.860300  0.034271    1.772802
# 44            0.336379  0.058565    0.624393  1.856215  0.027014    1.766793
# 47            0.336379  0.092116    0.622399  1.850289  0.042331    1.757466
# 51            0.336379  0.074106    0.619056  1.840352  0.033839    1.742045
# 55            0.336379  0.062556    0.614033  1.825418  0.028286    1.719372
# 59            0.336379  0.054151    0.611244  1.817125  0.024351    1.707034
# 6             0.336302  0.148001    0.578097  1.718984  0.061903    1.573107
# 22            0.146167  0.072605    0.576383  3.943325  0.054193    2.015580
# 2             0.182620  0.084023    0.574840  3.147747  0.057330    1.922525
# 12            0.336379  0.146289    0.571410  1.698707  0.060171    1.548381
# 26            0.336302  0.101877    0.566658  1.684971  0.041415    1.531583
# 31            0.336379  0.189334    0.562990  1.673675  0.076209    1.518547
# 30            0.336302  0.189334    0.562859  1.673675  0.076209    1.518272
# 15            0.336302  0.119708    0.561975  1.671044  0.048071    1.515206
# 0             0.182620  0.070371    0.558644  3.059060  0.047367    1.851977
# 29            0.336302  0.072127    0.556575  1.654989  0.028546    1.496756
# 19            0.336379  0.118452    0.556077  1.653126  0.046799    1.494902
# 24            0.336302  0.063756    0.555233  1.650997  0.025139    1.492238
# 28            0.336302  0.088592    0.552674  1.643387  0.034684    1.483700
# 32            0.336302  0.068292    0.547895  1.629178  0.026374    1.468019
# 23            0.336302  0.056541    0.547294  1.627389  0.021798    1.466068
# 39            0.336379  0.067936    0.545041  1.620316  0.026008    1.458638
# 35            0.336379  0.097797    0.543965  1.617117  0.037321    1.455196
# 27            0.336302  0.053629    0.542815  1.614073  0.020403    1.451708
# 34            0.336379  0.061677    0.537128  1.596794  0.023052    1.433704
# 37            0.336379  0.086024    0.536653  1.595380  0.032103    1.432233
#
#     zhangs_metric
# 56       0.525648
# 46       0.545758
# 58       0.509593
# 41       0.513962
# 50       0.524591
# 44       0.509012
# 47       0.539372
# 51       0.518721
# 55       0.503472
# 59       0.493391
# 6        0.562190
# 22       0.853980
# 2        0.799117
# 12       0.552856
# 26       0.495624
# 31       0.606469
# 30       0.606540
# 15       0.510265
# 0        0.770111
# 29       0.454690
# 19       0.502023
# 24       0.445456
# 28       0.466237
# 32       0.441185
# 23       0.429936
# 39       0.437350
# 35       0.465263
# 27       0.422157
# 34       0.422229
# 37       0.444431

# %%
 veri2=dat.iloc[:,1]
 verie=pd.DataFrame(veri2)
 verie
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            list_of_goods
# 0      ['olive oil', 'yogurt cake', 'grated cheese', ...
# 1      ['babies food', 'shower gel', 'rice', 'black b...
# 2      ['babies food', 'barbecue sauce', 'olive oil',...
# 3      ['babies food', 'milk', 'rice', 'yogurt cake',...
# 4      ['napkins', 'cookies', 'razor', 'cooking oil',...
# ...                                                  ...
# 89947  ['rice', 'pet food', 'cauliflower', 'cake', 'c...
# 89948  ['cotton buds', 'cream', 'gums', 'cooking oil'...
# 89949  ['cottage cheese', 'champagne', 'spaghetti', '...
# 89950  ['chutney', 'samsung galaxy 10', 'catfish', 't...
# 89951  ['cotton buds', 'phone car charger', 'cooking ...
#
# [89952 rows x 1 columns]

# %%
import pandas as pd
from ast import literal_eval  # Import literal_eval to safely evaluate strings containing Python expressions

# Assuming 'veri' is your DataFrame with the column 'list_of_goods'
verie['list_of_goods'] = verie['list_of_goods'].apply(lambda x: literal_eval(x) if isinstance(x, str) else x)

# Convert each row to a string with comma-separated items
verie['list_of_goods'] = verie['list_of_goods'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

print(verie)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            list_of_goods
# 0      olive oil, yogurt cake, grated cheese, cookies...
# 1      babies food, shower gel, rice, black beer, oli...
# 2      babies food, barbecue sauce, olive oil, butter...
# 3      babies food, milk, rice, yogurt cake, gums, st...
# 4      napkins, cookies, razor, cooking oil, water sp...
# ...                                                  ...
# 89947  rice, pet food, cauliflower, cake, cooking oil...
# 89948  cotton buds, cream, gums, cooking oil, cake, c...
# 89949  cottage cheese, champagne, spaghetti, vacuum c...
# 89950  chutney, samsung galaxy 10, catfish, tea, hone...
# 89951  cotton buds, phone car charger, cooking oil, c...
#
# [89952 rows x 1 columns]

# %%
verie=list(verie["list_of_goods"].apply(lambda x:x.split(",")))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
veri2e=pd.DataFrame(verie)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(veri2e)
# Out:
#                    0                   1               2                3   \
# 0           olive oil         yogurt cake   grated cheese          cookies
# 1         babies food          shower gel            rice       black beer
# 2         babies food      barbecue sauce       olive oil           butter
# 3         babies food                milk            rice      yogurt cake
# 4             napkins             cookies           razor      cooking oil
# ...               ...                 ...             ...              ...
# 89947            rice            pet food     cauliflower             cake
# 89948     cotton buds               cream            gums      cooking oil
# 89949  cottage cheese           champagne       spaghetti   vacuum cleaner
# 89950         chutney   samsung galaxy 10         catfish              tea
# 89951     cotton buds   phone car charger     cooking oil             cake
#
#                     4                   5                6   \
# 0              ketchup         cooking oil            pasta
# 1            olive oil       fromage blanc          cereals
# 2                 gums   final fantasy XIX      cooking oil
# 3                 gums        strawberries      cooking oil
# 4          water spray                 oil             None
# ...                ...                 ...              ...
# 89947      cooking oil                 oil       candy bars
# 89948             cake             chicken            pasta
# 89949   pokemon violet                mint   pokemon shield
# 89950            honey             almonds        deodorant
# 89951     french fries          candy bars             salt
#
#                       7                  8                  9         10  \
# 0       whole wheat rice                oil          asparagus      None
# 1                   cake               soup              pasta   seabass
# 2                   cake           sandwich            seabass       oil
# 3              green tea           portal 2                oil      None
# 4                   None               None               None      None
# ...                  ...                ...                ...       ...
# 89947     metroid fusion      phone charger   whole wheat rice   muffins
# 89948          flax seed               None               None      None
# 89949               None               None               None      None
# 89950               None               None               None      None
# 89951             portal   whole wheat rice           eggplant      None
#
#                       11        12        13           14    15    16    17  \
# 0                   None      None      None         None  None  None  None
# 1       whole wheat rice   spinach   muffins   mayonnaise   oil  None  None
# 2                   None      None      None         None  None  None  None
# 3                   None      None      None         None  None  None  None
# 4                   None      None      None         None  None  None  None
# ...                  ...       ...       ...          ...   ...   ...   ...
# 89947        canned_tuna      None      None         None  None  None  None
# 89948               None      None      None         None  None  None  None
# 89949               None      None      None         None  None  None  None
# 89950               None      None      None         None  None  None  None
# 89951               None      None      None         None  None  None  None
#
#          18    19
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# ...     ...   ...
# 89947  None  None
# 89948  None  None
# 89949  None  None
# 89950  None  None
# 89951  None  None
#
# [89952 rows x 20 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !pip install pyECLAT
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Collecting pyECLAT
#   Downloading pyECLAT-1.0.2-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (2.0.3)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (1.25.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from pyECLAT) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->pyECLAT) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->pyECLAT) (1.16.0)
# Installing collected packages: pyECLAT
# Successfully installed pyECLAT-1.0.2

# %%
from pyECLAT import ECLAT
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
minürün=2
minsupport=0.1
maxürün=max([len(x) for x in verie])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ec=ECLAT(veri2e,verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 100%|██████████| 325/325 [00:52<00:00,  6.23it/s]
# 100%|██████████| 325/325 [00:01<00:00, 285.88it/s]
# 100%|██████████| 325/325 [00:00<00:00, 1295.79it/s]

# %%
a,b=ec.fit(min_support=minsupport,min_combination=minürün,max_combination=maxürün)
print(b)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Combination 2 by 2
# 120it [00:02, 41.17it/s]
# Combination 3 by 3
# 560it [00:09, 57.77it/s]
# Combination 4 by 4
# 1820it [00:27, 66.57it/s]
# Combination 5 by 5
# 4368it [01:07, 65.08it/s]
# Combination 6 by 6
# 8008it [02:11, 60.92it/s]
# Combination 7 by 7
# 11440it [03:14, 58.76it/s]
# Combination 8 by 8
# 12870it [03:42, 57.74it/s]
# Combination 9 by 9
# 11440it [03:25, 55.72it/s]
# Combination 10 by 10
# 8008it [02:26, 54.65it/s]
# Combination 11 by 11
# 4368it [01:25, 51.26it/s]
# Combination 12 by 12
# 1820it [00:35, 51.85it/s]
# Combination 13 by 13
# 560it [00:11, 47.73it/s]
# Combination 14 by 14
# 120it [00:02, 43.16it/s]
# Combination 15 by 15
# 16it [00:00, 28.75it/s]
# Combination 16 by 16
# 1it [00:00, 30.91it/s]
# Combination 17 by 17
# 0it [00:00, ?it/s]
# Combination 18 by 18
# 0it [00:00, ?it/s]
# Combination 19 by 19
# 0it [00:00, ?it/s]
# Combination 20 by 20
# 0it [00:00, ?it/s]
# {' oil &  cake': 0.14628913198150126, ' oil &  cooking oil': 0.18933431163287087, ' oil &  candy bars': 0.11845206332266098, ' cake &  cooking oil': 0.1480011561721807, ' cooking oil &  gums': 0.10187655638562788, ' cooking oil &  candy bars': 0.11970828886517254, ' cooking oil & babies food': 0.10391097474208466}
